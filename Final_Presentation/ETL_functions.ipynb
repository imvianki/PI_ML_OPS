# %%
from datetime import datetime
import pandas as pd
import numpy as np
import ast

# %%
with open('../Datasets/steam_games.json', 'r') as file:
    data_list = [ast.literal_eval(record) for record in file.readlines()]

data = pd.DataFrame(data_list)
data
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty
# 1                     Ironbound                 Ironbound
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                       弹炸人2222                   弹炸人2222
# 4                 Log Challenge                       NaN
# ...                         ...                       ...
# 32130            Colony On Mars            Colony On Mars
# 32131  LOGistICAL: South Africa  LOGistICAL: South Africa
# 32132             Russian Roads             Russian Roads
# 32133       EXIT 2 - Directions       EXIT 2 - Directions
# 32134               Maze Run VR                       NaN
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/773570/Log_C...          NaN
# ...                                                  ...          ...
# 32130  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 32131  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 32132  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 32133  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 32134  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4                        [Action, Indie, Casual, Sports]            1.79
# ...                                                  ...             ...
# 32130              [Strategy, Indie, Casual, Simulation]            1.49
# 32131                          [Strategy, Indie, Casual]            4.24
# 32132                        [Indie, Simulation, Racing]            1.39
# 32133  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/773570/reviews/?...
# ...                                                  ...
# 32130  http://steamcommunity.com/app/773640/reviews/?...
# 32131  http://steamcommunity.com/app/733530/reviews/?...
# 32132  http://steamcommunity.com/app/610660/reviews/?...
# 32133  http://steamcommunity.com/app/658870/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access      id                 developer        sentiment  \
# 0             False  761140                 Kotoshiro              NaN
# 1             False  643980          Secret Level SRL  Mostly Positive
# 2             False  670290              Poolians.com  Mostly Positive
# 3             False  767400                      彼岸领域              NaN
# 4             False  773570                       NaN              NaN
# ...             ...     ...                       ...              ...
# 32130         False  773640        Nikita "Ghost_RUS"              NaN
# 32131         False  733530                    Sacada              NaN
# 32132         False  610660  Laush Dmitriy Sergeevich              NaN
# 32133         False  658870             xropi,stev3ns   1 user reviews
# 32134          True  681550                       NaN         Positive
#
#       metascore
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 32130       NaN
# 32131       NaN
# 32132       NaN
# 32133       NaN
# 32134       NaN
#
# [32135 rows x 16 columns]

# %% [markdown]
# ## 1. Limpieza de datos para las funciones

# %%
# filtrado de datos que no son de formato "YYYY-MM-DD"
data[pd.to_datetime(data['release_date'], format='%Y-%m-%d', errors='coerce').isna()]
# Out:
#                             publisher  \
# 4                                 NaN
# 10                            Qucheza
# 11                                NaN
# 19                                NaN
# 20                                NaN
# ...                               ...
# 32087  Greyson Richey, Nicholas Lives
# 32088                rechargecomplete
# 32097             Lunar Giant Studios
# 32123                         VersoVR
# 32134                             NaN
#
#                                                   genres  \
# 4                                                    NaN
# 10             [Action, Indie, Simulation, Early Access]
# 11                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# ...                                                  ...
# 32087                [Action, Casual, Indie, Simulation]
# 32088           [Action, Adventure, Indie, Early Access]
# 32097                                    [Action, Indie]
# 32123  [Casual, Indie, Simulation, Sports, Early Access]
# 32134                                                NaN
#
#                    app_name              title  \
# 4             Log Challenge                NaN
# 10          Uncanny Islands    Uncanny Islands
# 11     Icarus Six Sixty Six                NaN
# 19            After Life VR                NaN
# 20               Kitty Hawk                NaN
# ...                     ...                ...
# 32087      Lonely Astronaut   Lonely Astronaut
# 32088     RECHARGE COMPLETE  RECHARGE COMPLETE
# 32097            Tetrapulse         Tetrapulse
# 32123          Cricket Club       Cricket Club
# 32134           Maze Run VR                NaN
#
#                                                      url  release_date  \
# 4      http://store.steampowered.com/app/773570/Log_C...           NaN
# 10     http://store.steampowered.com/app/768570/Uncan...        Soon..
# 11     http://store.steampowered.com/app/724910/Icaru...           NaN
# 19     http://store.steampowered.com/app/772590/After...           NaN
# 20     http://store.steampowered.com/app/640250/Kitty...           NaN
# ...                                                  ...           ...
# 32087  http://store.steampowered.com/app/755830/Lonel...   Coming Soon
# 32088  http://store.steampowered.com/app/708070/RECHA...           NaN
# 32097  http://store.steampowered.com/app/250440/Tetra...          2016
# 32123  http://store.steampowered.com/app/772180/Crick...  January 2018
# 32134  http://store.steampowered.com/app/681550/Maze_...           NaN
#
#                                                     tags  discount_price  \
# 4                        [Action, Indie, Casual, Sports]            1.79
# 10     [Early Access, Action, Indie, Simulation, Surv...             NaN
# 11                                              [Casual]             NaN
# 19                             [Early Access, Indie, VR]             NaN
# 20      [Early Access, Action, Adventure, Indie, Casual]            1.97
# ...                                                  ...             ...
# 32087                [Casual, Action, Indie, Simulation]             NaN
# 32088           [Early Access, Action, Adventure, Indie]             NaN
# 32097                             [Indie, Action, Co-op]             NaN
# 32123  [Early Access, Indie, Casual, Simulation, Sports]             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url  \
# 4      http://steamcommunity.com/app/773570/reviews/?...
# 10     http://steamcommunity.com/app/768570/reviews/?...
# 11     http://steamcommunity.com/app/724910/reviews/?...
# 19     http://steamcommunity.com/app/772590/reviews/?...
# 20     http://steamcommunity.com/app/640250/reviews/?...
# ...                                                  ...
# 32087  http://steamcommunity.com/app/755830/reviews/?...
# 32088  http://steamcommunity.com/app/708070/reviews/?...
# 32097  http://steamcommunity.com/app/250440/reviews/?...
# 32123  http://steamcommunity.com/app/772180/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs price  early_access  \
# 4      [Single-player, Full controller support, HTC V...  2.99         False
# 10                                       [Single-player]   NaN          True
# 11     [Single-player, HTC Vive, Tracked Motion Contr...  Free         False
# 19     [Single-player, HTC Vive, Tracked Motion Contr...  4.99          True
# 20     [Single-player, Steam Leaderboards, HTC Vive, ...  2.99          True
# ...                                                  ...   ...           ...
# 32087                                    [Single-player]   NaN         False
# 32088                [Single-player, Steam Achievements]   NaN          True
# 32097  [Multi-player, Co-op, Shared/Split Screen, Ste...   NaN         False
# 32123                                    [Single-player]   NaN          True
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...  4.99          True
#
#            id                      developer sentiment metascore
# 4      773570                            NaN       NaN       NaN
# 10     768570                        Qucheza       NaN       NaN
# 11     724910                            NaN       NaN       NaN
# 19     772590                            NaN       NaN       NaN
# 20     640250                            NaN       NaN       NaN
# ...       ...                            ...       ...       ...
# 32087  755830  Greyson Richey,Nicholas Lives       NaN       NaN
# 32088  708070               rechargecomplete       NaN       NaN
# 32097  250440                    The Amiable       NaN       NaN
# 32123  772180                        VersoVR       NaN       NaN
# 32134  681550                            NaN  Positive       NaN
#
# [2352 rows x 16 columns]

# %% [markdown]
# La siguiente función convierte diferentes formatos de fechas al estándar '%Y-%m-%d'. Debido a que no se quiere modificar la columna original release_date para futuros cálculos, se creó otra columa llamada 'modify_date' donde se encuentran los valores con formato modificado.

# %%
def get_format(date):
    formats_list = ['%Y-%m-%d', '%d.%m.%Y', '%b %Y', '%b-%y', '%B %Y', '%Y', '%d %b, %Y']
    for formats in formats_list:
        try:
            parsed_date = datetime.strptime(date, formats)
            if parsed_date.strftime(formats) == date:
                return parsed_date.date().strftime('%Y-%m-%d')
        except ValueError:
            continue
        except TypeError:
            return np.nan
    return np.nan

data['modify_date'] = data['release_date'].apply(get_format)
data
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty
# 1                     Ironbound                 Ironbound
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                       弹炸人2222                   弹炸人2222
# 4                 Log Challenge                       NaN
# ...                         ...                       ...
# 32130            Colony On Mars            Colony On Mars
# 32131  LOGistICAL: South Africa  LOGistICAL: South Africa
# 32132             Russian Roads             Russian Roads
# 32133       EXIT 2 - Directions       EXIT 2 - Directions
# 32134               Maze Run VR                       NaN
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/773570/Log_C...          NaN
# ...                                                  ...          ...
# 32130  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 32131  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 32132  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 32133  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 32134  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4                        [Action, Indie, Casual, Sports]            1.79
# ...                                                  ...             ...
# 32130              [Strategy, Indie, Casual, Simulation]            1.49
# 32131                          [Strategy, Indie, Casual]            4.24
# 32132                        [Indie, Simulation, Racing]            1.39
# 32133  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/773570/reviews/?...
# ...                                                  ...
# 32130  http://steamcommunity.com/app/773640/reviews/?...
# 32131  http://steamcommunity.com/app/733530/reviews/?...
# 32132  http://steamcommunity.com/app/610660/reviews/?...
# 32133  http://steamcommunity.com/app/658870/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access      id                 developer        sentiment  \
# 0             False  761140                 Kotoshiro              NaN
# 1             False  643980          Secret Level SRL  Mostly Positive
# 2             False  670290              Poolians.com  Mostly Positive
# 3             False  767400                      彼岸领域              NaN
# 4             False  773570                       NaN              NaN
# ...             ...     ...                       ...              ...
# 32130         False  773640        Nikita "Ghost_RUS"              NaN
# 32131         False  733530                    Sacada              NaN
# 32132         False  610660  Laush Dmitriy Sergeevich              NaN
# 32133         False  658870             xropi,stev3ns   1 user reviews
# 32134          True  681550                       NaN         Positive
#
#       metascore modify_date
# 0           NaN  2018-01-04
# 1           NaN  2018-01-04
# 2           NaN  2017-07-24
# 3           NaN  2017-12-07
# 4           NaN         NaN
# ...         ...         ...
# 32130       NaN  2018-01-04
# 32131       NaN  2018-01-04
# 32132       NaN  2018-01-04
# 32133       NaN  2017-09-02
# 32134       NaN         NaN
#
# [32135 rows x 17 columns]

# %%
# Eliminamos los valores NaN de la columna 'modify_date'
data.dropna(subset=['modify_date'], inplace=True, ignore_index=True)

# %% [markdown]
# Se creó otra columna llamada 'year' cuyos valores son el año extraído de la columna 'modify_date'

# %%
data['modify_date'] = pd.to_datetime(data['modify_date'])
data['year'] = data['modify_date'].dt.year
data
# Out:
#                  publisher                                             genres  \
# 0                Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1         Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2             Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                     彼岸领域                        [Action, Adventure, Casual]
# 4      Trickjump Games Ltd                    [Action, Adventure, Simulation]
# ...                    ...                                                ...
# 29889      Bidoniera Games                 [Action, Adventure, Casual, Indie]
# 29890      Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 29891               Sacada                          [Casual, Indie, Strategy]
# 29892         Laush Studio                        [Indie, Racing, Simulation]
# 29893             SIXNAILS                                    [Casual, Indie]
#
#                        app_name                     title  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty
# 1                     Ironbound                 Ironbound
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                       弹炸人2222                   弹炸人2222
# 4         Battle Royale Trainer     Battle Royale Trainer
# ...                         ...                       ...
# 29889              Kebab it Up!              Kebab it Up!
# 29890            Colony On Mars            Colony On Mars
# 29891  LOGistICAL: South Africa  LOGistICAL: South Africa
# 29892             Russian Roads             Russian Roads
# 29893       EXIT 2 - Directions       EXIT 2 - Directions
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/772540/Battl...   2018-01-04
# ...                                                  ...          ...
# 29889  http://store.steampowered.com/app/745400/Kebab...   2018-01-04
# 29890  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 29891  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 29892  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 29893  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4      [Action, Adventure, Simulation, FPS, Shooter, ...             NaN
# ...                                                  ...             ...
# 29889        [Action, Indie, Casual, Violent, Adventure]            1.69
# 29890              [Strategy, Indie, Casual, Simulation]            1.49
# 29891                          [Strategy, Indie, Casual]            4.24
# 29892                        [Indie, Simulation, Racing]            1.39
# 29893  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/772540/reviews/?...
# ...                                                  ...
# 29889  http://steamcommunity.com/app/745400/reviews/?...
# 29890  http://steamcommunity.com/app/773640/reviews/?...
# 29891  http://steamcommunity.com/app/733530/reviews/?...
# 29892  http://steamcommunity.com/app/610660/reviews/?...
# 29893  http://steamcommunity.com/app/658870/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4                    [Single-player, Steam Achievements]          3.99
# ...                                                  ...           ...
# 29889   [Single-player, Steam Achievements, Steam Cloud]          1.99
# 29890                [Single-player, Steam Achievements]          1.99
# 29891  [Single-player, Steam Achievements, Steam Clou...          4.99
# 29892  [Single-player, Steam Achievements, Steam Trad...          1.99
# 29893   [Single-player, Steam Achievements, Steam Cloud]          4.99
#
#        early_access      id                 developer        sentiment  \
# 0             False  761140                 Kotoshiro              NaN
# 1             False  643980          Secret Level SRL  Mostly Positive
# 2             False  670290              Poolians.com  Mostly Positive
# 3             False  767400                      彼岸领域              NaN
# 4             False  772540       Trickjump Games Ltd            Mixed
# ...             ...     ...                       ...              ...
# 29889         False  745400           Bidoniera Games   2 user reviews
# 29890         False  773640        Nikita "Ghost_RUS"              NaN
# 29891         False  733530                    Sacada              NaN
# 29892         False  610660  Laush Dmitriy Sergeevich              NaN
# 29893         False  658870             xropi,stev3ns   1 user reviews
#
#       metascore modify_date  year
# 0           NaN  2018-01-04  2018
# 1           NaN  2018-01-04  2018
# 2           NaN  2017-07-24  2017
# 3           NaN  2017-12-07  2017
# 4           NaN  2018-01-04  2018
# ...         ...         ...   ...
# 29889       NaN  2018-01-04  2018
# 29890       NaN  2018-01-04  2018
# 29891       NaN  2018-01-04  2018
# 29892       NaN  2018-01-04  2018
# 29893       NaN  2017-09-02  2017
#
# [29894 rows x 18 columns]

# %%
# Convierte los datos de year a string
data['year'] = data['year'].astype(str)

# %%
# Guardar archivo limpio
data.to_csv('../Datasets/data.csv')

# %% [markdown]
# ## 2. Creación de Funciones

# %% [markdown]
# Las funciones siguientes no han requerido de eliminación de datos para las otras columnas que no sean año.

# %% [markdown]
# ### Función #1

# %%
# Se ingresa un año y devuelve un diccionario con los 5 géneros más vendidos en el orden correspondiente.

def get_genre(year):
    filtered_genre = data[data['year'] == str(year)]
    genres = [genre for lista in filtered_genre['genres'] if isinstance(lista, list) for genre in lista if pd.notna(genre)]
    genres_dict = {genre: genres.count(genre) for genre in genres}
    top_genres = dict(sorted(genres_dict.items(), key=lambda x: x[1], reverse=True)[:5])
    return top_genres

get_genre(2018)
# Out:
# {'Indie': 97, 'Action': 57, 'Adventure': 57, 'Casual': 37, 'Simulation': 37}

# %% [markdown]
# ### Función #2

# %%
# Se ingresa un año y devuelve una lista con los juegos lanzados en el año.

def get_games(year):
    filtered_games = data[data['year'] == str(year)]
    games_list = [game for game in filtered_games['app_name'].unique() if pd.notna(game)]
    games_dict = {year: games_list}
    return games_dict

get_games(2014)
# Out:
# {2014: ['Imagine Earth',
#   'BeatBlasters III',
#   'Blood of the Werewolf',
#   "Broken Sword 5 - the Serpent's Curse",
#   'Particulars',
#   'Episode 3 - The Fisherman and His Wife',
#   'Episode 4 - Puss in Boots',
#   'Episode 8 - Beauty and the Beast',
#   'Episode 5 - The Girl Without Hands',
#   'Episode 7 - The Devil and His Three Golden Hairs',
#   'Episode 6 - Godfather Death',
#   'Episode 9 - The Master Thief',
#   'Magic 2014 “Warsmith” Foil Conversion',
#   'Episode 10 - The Singing Bone',
#   'Rocksmith® 2014 – Aerosmith Song Pack',
#   'Magic 2014 “Warsmith” Deck Key',
#   'Magic 2014 “Hunting Season” Foil Conversion',
#   'Magic 2014 “Hunting Season” Deck Key',
#   'Magic 2014 - Deck Pack 3',
#   'CONSORTIUM',
#   'Nidhogg',
#   'Galcon Legends',
#   'Awesomenauts - SUSI Announcer',
#   'Saints Row IV - Stone Age Pack',
#   'Assassin’s Creed® Liberation HD',
#   'Train Simulator: West Coast Main Line Over Shap Route Add-On',
#   'Assassin’s Creed® Liberation HD - Bonus Pack',
#   "Loren The Amazon Princess - The Castle Of N'Mar DLC",
#   'SpellForce 2 - Demons of the Past',
#   'Humans Must Answer',
#   'Estranged: Act I',
#   'SpellForce 2 - Demons of the Past - Soundtrack',
#   'Insurgency',
#   'Blast Em!',
#   'Blast Em! Source Code',
#   'Hero Siege',
#   'Broken Age - Soundtrack',
#   'Our Darker Purpose',
#   'The Castle Doctrine',
#   'Saturday Morning RPG',
#   'Star Swarm Stress Test',
#   "Train Simulator: Amtrak P42 DC 'Empire Builder' Loco Add-On",
#   "King's Bounty: Warriors of the North - Ice and Fire",
#   'rymdkapsel',
#   'Serena',
#   'PAYDAY 2: Gage Weapon Pack #02',
#   'Octodad: Dadliest Catch',
#   'RPG Maker VX Ace - Inspirational Vol. 2',
#   'Aqua Kitty - Milk Mine Defender',
#   'Rocksmith® 2014 – R.E.M. - “What’s the Frequency, Kenneth?”',
#   'Waves Soundtrack',
#   'Sword of the Stars: The Pit Soundtrack',
#   'Rocksmith® 2014 – R.E.M. - “Everybody Hurts”',
#   'Rocksmith® 2014 – R.E.M. - “The One I Love”',
#   'Rocksmith® 2014 – R.E.M. - “Überlin”',
#   'Rocksmith® 2014 – R.E.M. - “Shiny, Happy People”',
#   'Rocksmith® 2014 – STRAIGHTENER - “ROCKSTEADY”',
#   'Rocksmith® 2014 – STRAIGHTENER - “From Noon Till Dawn”',
#   'Rocksmith® 2014 – R.E.M. Song Pack',
#   'Agarest: Generations of War',
#   'GTGD S1: More Than a Gamer',
#   'BlazBlue: Calamity Trigger',
#   'Kingdom Tales',
#   'Disciples III: Reincarnation',
#   'NaissanceE',
#   'Train Simulator: Canadian Mountain Passes: Revelstoke-Lake Louise',
#   'Crusader Kings II: Saxon Unit Pack',
#   'Crusader Kings II: Finno-Ugric Unit Pack',
#   'LocoCycle',
#   'Eschalon: Book III',
#   'Girls Like Robots',
#   'METAL SLUG 3',
#   'Cube & Star: An Arbitrary Love',
#   'Card City Nights',
#   'Rocksmith® 2014 – The Birthday - “stupid”',
#   'Rocksmith® 2014 – RIZE - “PARADOX Taiso”',
#   'Rocksmith® 2014 – ACIDMAN - “Shinsekai”',
#   'Rocksmith® 2014 – Rise Against - “Prayer of the Refugee”',
#   'Rocksmith® 2014 – Rise Against - “Give It All”',
#   'Rocksmith® 2014 – Rise Against - “Make It Stop (September’s Children)”',
#   'Banished',
#   'Ikaruga',
#   'Rocksmith® 2014 – Rise Against - “Satellite”',
#   'Rocksmith® 2014 – Rise Against Song Pack',
#   'Rocksmith® 2014 – Rise Against - “Swing Life Away”',
#   '7 Wonders of the Ancient World',
#   '7 Wonders: Magical Mystery Tour',
#   'Hexcells',
#   'Hexcells Plus',
#   'PAYDAY 2: The Death Wish Update',
#   'MorphVOX - Special Effects Voices',
#   'Call of Duty®: Ghosts - Onslaught',
#   'Europa Universalis IV: Colonial British and French Unit pack',
#   'Rocksmith® 2014 – The Doors - “Light My Fire”',
#   'Rocksmith® 2014 – The Doors - “Riders on the Storm”',
#   'Rocksmith® 2014 – The Doors - “Roadhouse Blues”',
#   'Rocksmith® 2014 – The Doors Song Pack',
#   'PAC-MAN MUSEUM Demo',
#   'Epic Battle Fantasy 4',
#   'Ultionus: A Tale of Petty Revenge',
#   "Assassin's Creed Freedom Cry",
#   'Castlevania: Lords of Shadow 2',
#   'Talisman - Character Pack #1 - Exorcist',
#   'Talisman: Digital Edition',
#   'Windforge',
#   'Galactic Command Echo Squad SE - Demo',
#   'PAC-MAN MUSEUM™ - Ms. PAC-MAN™ DLC',
#   'Towtruck Simulator 2015',
#   'Cities in Motion 2: European Cities',
#   'Talisman - Complete Runestone Deck',
#   'Dominique Pamplemousse',
#   'Rocksmith® 2014 – Heart - “Crazy On You”',
#   'Rocksmith® 2014 – Halestorm - “Love Bites (So Do I)”',
#   'Dominique Pamplemousse: Soundtrack & Sheet Music',
#   'Eets Munchies',
#   '1954 Alcatraz',
#   'TowerFall Ascension',
#   'Rocksmith® 2014 – Flyleaf - “All Around Me”',
#   'Dark Shadows - Army of Evil',
#   'Constant C',
#   'Space Hulk - Space Wolves Chapter',
#   'C9: Premium Package',
#   'ComiPo! Casual Wear',
#   'ComiPo! Swim Wear',
#   'C9: Steam Beginners Package',
#   'ComiPo! Summer Uniform & Sportswear',
#   'Batch Converter Plugin',
#   'Braveland',
#   'LYNE',
#   'Alpha Kimori™ 1',
#   'Deus Ex: The Fall',
#   'LUFTRAUSERS',
#   'Ku: Shroud of the Morrigan',
#   'Danmaku Unlimited 2',
#   'Rocksmith® 2014 – A Day To Remember - “All I Want”',
#   'BioShock Infinite: Burial at Sea - Episode Two',
#   'Rocksmith® 2014 – A Day To Remember - “It’s Complicated”',
#   'Rocksmith® 2014 – A Day To Remember - “The Downfall of Us All”',
#   'Train Simulator: DB BR 145 Loco Add-On',
#   'Cloudbuilt',
#   'Influent',
#   'Influent DLC - Deutsch [Learn German]',
#   'Influent DLC - 한국어 [Learn Korean]',
#   'Influent DLC - Latina [Learn Latin]',
#   'Influent DLC - български [Learn Bulgarian]',
#   'Influent DLC - Español [Learn Spanish]',
#   'Influent DLC - 普通话 [Learn Mandarin Chinese]',
#   'Influent DLC - English [Learn English]',
#   'Influent DLC - 日本語 [Learn Japanese]',
#   'Influent DLC - Français [Learn French]',
#   'Influent DLC - Svenska [Learn Swedish]',
#   "Heroine's Quest: The Herald of Ragnarok",
#   'Anmynor Puzzles',
#   'My Pet Hotel',
#   'Castlevania: Lords of Shadow 2 - Armored Dracula Costume',
#   'Castlevania: Lords of Shadow 2 - Dark Dracula Costume',
#   'Castlevania: Lords of Shadow 2 - Relic Rune Pack',
#   'Rocksmith® 2014 – Matchbox Twenty - “3AM”',
#   'Gardens Inc. – From Rakes to Riches',
#   'Rocksmith® 2014 – Matchbox Twenty - “Push”',
#   'Rocksmith® 2014 – Matchbox Twenty - “How Far We’ve Come”',
#   'Rocksmith® 2014 – Matchbox Twenty - “She’s So Mean”',
#   'Mercenary Kings',
#   'Quest of Dungeons',
#   'Rocksmith® 2014 – Matchbox Twenty Song Pack',
#   'Calibre 10 Racing',
#   'Rocksmith® 2014 – Matchbox Twenty - “Unwell”',
#   'Train Simulator: Dispolok BR 189 Loco Add-On',
#   'Total War: ROME II - Hannibal at the Gates Campaign Pack',
#   "The Witch's Yarn",
#   'Scourge: Outbreak - Blindside PvP Map pack',
#   'FaeVerse Alchemy',
#   '2014 Edition Add-on - Masters of the World DLC',
#   'Call of Duty®: Ghosts - Zakhaev Special Character',
#   'Call of Duty®: Ghosts - Legend Pack - Makarov',
#   'Call of Duty®: Ghosts - Rorke Special Character',
#   'Actual Sunlight',
#   'Euro Truck Simulator 2 - Force of Nature Paint Jobs Pack',
#   'Half Minute Hero: The Second Coming',
#   'GTGD S2: Just One Dev',
#   'Halo: Spartan Assault',
#   'Leadwerks Game Engine - Professional Edition',
#   'Evolution RTS',
#   "House of 1,000 Doors: Family Secrets Collector's Edition",
#   'Motte Island',
#   'Munich Bus Simulator',
#   'Paper Dungeons',
#   'Rocksmith® 2014 – Bob Dylan - “Just Like a Woman”',
#   'Zoom Player 13 : Steam Edition',
#   'Rocksmith® 2014 – Bob Dylan - “Like a Rolling Stone”',
#   'Rocksmith® 2014 – Bob Dylan - “Subterranean Homesick Blues”',
#   'Smugglers 5',
#   'Volt',
#   'Hive - The Ladybug',
#   'Krita Gemini',
#   'BR Provincial Sector Class 143 Add-on Livery',
#   'Secrets of Rætikon',
#   'Secrets of Rætikon - Soundtrack',
#   'Space Farmers',
#   'Pixel Puzzles: Japan',
#   "Robin's Quest",
#   'Heldric - The legend of the shoemaker Demo',
#   'Heldric - The legend of the shoemaker',
#   'Agarest: Generations of War Zero',
#   'Villagers and Heroes',
#   'Circuits',
#   'Uprising44: The Silent Shadows',
#   'Dracula: The Resurrection',
#   'Abalone',
#   'FarSky',
#   'Among the Sleep Demo',
#   'Rabbit Hole 3D: Steam Edition',
#   'Depths of Fear :: Knossos',
#   'Spice Road',
#   'Nostradamus: The Last Prophecy',
#   'Rogue Shooter: The FPS Roguelike',
#   'Rogue Shooter: The FPS Roguelike Demo',
#   'Stardust Pack',
#   'Nicolas Eymerich - The Inquisitor - Book 1 : The Plague',
#   'Croixleur Sigma',
#   'Kovac’s Way DLC',
#   'F-15C for DCS World',
#   'Wing IDE 5 - Commercial Use',
#   'Wing IDE 5',
#   'Black Rainbow',
#   'BloodRayne Betrayal',
#   'Serious Sam Classics: Revolution',
#   'Train Simulator: BR Class 20 Loco Add-On',
#   'Into the Dark: Ultimate Trash Edition',
#   'The Final Stand',
#   'Jet Car Stunts',
#   'Full Bore',
#   'Croixleur Sigma Demo',
#   'Sweezy Gunner',
#   'Outlast: Whistleblower DLC',
#   'Rocksmith® 2014 – 311 - “Down”',
#   'Indie Graphics Bundle - Royalty Free Sprites',
#   'Rocksmith® 2014 – 311 - “Beautiful Disaster”',
#   'Rocksmith® 2014 – 311 - “Amber”',
#   'Rocksmith® 2014 – 311 Song Pack',
#   'The Whispered World Special Edition',
#   'Back To Life 2',
#   'Descent: FreeSpace – The Great War',
#   'Blade Symphony',
#   'Democracy 3: Extremism',
#   'Fantasy Grounds - PFRPG Basic Paths: Fangs from the Past',
#   'Fistful of Frags',
#   'Coldfire Keep',
#   'Ground Pounders - High Rez Pack',
#   'Lili: Child of Geos - Complete Edition',
#   'Fantasy Grounds',
#   'Chronology',
#   'Coma: Mortuary',
#   'The Last Tinker™: City of Colors',
#   'Wildlife Park 3',
#   "Fantasy Grounds - C&C Castle Keeper's Guide",
#   'Gas Guzzlers Extreme: Full Metal Frenzy',
#   'World of Subways 3 – London Underground Circle Line',
#   "Fantasy Grounds - 3.5E/PFRPG: A00: Crow's Rest Island",
#   'Rocksmith® 2014 – Mastodon - “Oblivion”',
#   'Rocksmith® 2014 – Mastodon - “Black Tongue”',
#   'Organic Panic',
#   'Rocksmith® 2014 – Mastodon Song Pack',
#   'Train Simulator: Munich - Garmisch-Partenkirchen Route Add-On',
#   'Rocksmith® 2014 – Mastodon - “Colony Of Birchmen”',
#   'Awesomenauts - Giga Sentorii Skin',
#   'Hegemony Rome: The Rise of Caesar',
#   'DreadOut',
#   'DreadOut Soundtrack & Manga DLC',
#   'BattleBlock Theater®',
#   'Fearless Fantasy',
#   'Qbeh-1: The Atlas Cube',
#   'Orc Attack: Flatulent Rebellion',
#   'Men of War: Assault Squad 2',
#   'Vault Cracker',
#   'Graviteam Tactics: Volokonovka 1942',
#   'Agarest Zero - DLC Bundle #2',
#   'Monster Challenge Circus',
#   'Frederic: Resurrection of Music',
#   'Them - The Summoning',
#   'Shiny The Firefly',
#   'Men of War: Assault Squad 2 - Deluxe Edition upgrade',
#   'Rage Runner',
#   'Dark Scavenger',
#   'Pretentious Game',
#   'Transistor: Original Soundtrack',
#   'QUALIA 3: Multi Agent Soundtrack',
#   "Legionwood 2: Rise of the Eternal's Realm - Director's Cut",
#   'Sweet Lily Dreams',
#   'DRAKERZ-Confrontation',
#   'DRAKERZ-Confrontation : 12 virtual BOOSTERS',
#   'DRAKERZ-Confrontation : 36 virtual BOOSTERS',
#   'DRAKERZ-Confrontation : virtual STARTER pack FURKHAN + OGAM',
#   'Paradigm Shift',
#   'Retro Game Crunch',
#   'Europa Universalis IV: Anthology of Alternate History',
#   'Crusader Kings II: Persian Portraits',
#   'DRAKERZ-Confrontation : virtual STARTER pack MELEON + KWARTZ',
#   'Crusader Kings II: Persian Unit Pack',
#   'Space Hulk - Harbinger of Torment Campaign',
#   'Euro Truck Simulator 2 - Metallic Paint Jobs Pack',
#   'White Noise Online',
#   'Killer is Dead - Nightmare Edition',
#   'Tropico 5',
#   'GAUGE',
#   'Fantasy Grounds - Creature Collection 4E - Heroic 1 Token Pack',
#   'Fantasy Grounds - Basic Roleplaying (BRP) Ruleset',
#   'Frederic: Evil Strikes Back',
#   'Frederic: Resurrection of Music Demo',
#   'Fantasy Grounds - Ultimate Upgrade',
#   'Fantasy Grounds - Rolemaster Classic Ruleset',
#   'PAYDAY 2: The Shadow Raid Heist',
#   'Dracula 4 and  5 - Special Steam Edition',
#   'Europa Universalis IV: Wealth of Nations E-book',
#   'Europa Universalis IV: Trade Nations Unit Pack',
#   'Expansion - Europa Universalis IV: Wealth of Nations',
#   'Europa Universalis IV: Muslim Ships Unit Pack',
#   'Arma 3 DLC Bundle 1',
#   'RPG Maker VX Ace - Royal Tiles Resource Pack',
#   'Arma 3 Karts',
#   'Anomaly Defenders',
#   'Where is my Heart?',
#   'Euro Truck Simulator 2 - Flip Paint Designs',
#   'Strata',
#   'HTR+ Slot Car Simulation',
#   'Agarest Zero - DLC Bundle #3',
#   'El Starter Pack 2.0',
#   'El Adventurer Pack 2.0',
#   'Defense Zone 2',
#   'GearCity',
#   'The Forest',
#   'State of Decay - Lifeline',
#   'The Fall',
#   'SPORT1 Live : Duel',
#   'Kill Fun Yeah',
#   'The Campaign Series: Fall Weiss',
#   'Dysan the Shapeshifter',
#   'EPOCH',
#   'Eador. Masters of the Broken World - Allied Forces',
#   'Richard & Alice',
#   'Galactic Arms Race',
#   'Nether: Resurrected',
#   'Kill The Bad Guy',
#   'BIT.TRIP FLUX',
#   'BIT.TRIP FLUX Soundtrack',
#   'Ludwig',
#   'Lifeless Planet Premier Edition',
#   'Electronic Super Joy: Groove City',
#   'Railroad X',
#   'Dead Bits (Soundtrack)',
#   'US Diesel Locomotives - Set 1',
#   'US Diesel Locomotives - Set 2',
#   'Magicite',
#   'Modelset 1 - Railstation, Houses, Barn',
#   'Shadows on the Vatican Act I: Greed',
#   'Rocksmith® 2014 – Bill Withers - “Ain’t No Sunshine”',
#   'Rocksmith® 2014 – Roy Buchanan - “Sweet Dreams”',
#   'Munin',
#   'Rocksmith® 2014 – James Gang - “Funk #49”',
#   'Echo of the Wilds',
#   'Enemy Front',
#   'Infinite Game Works Episode 0',
#   'Spy Chameleon - RGB Agent',
#   'Faery - Legends of Avalon',
#   "A Wizard's Lizard",
#   'DubWars Demo',
#   'Bot Colony',
#   'Xenonauts',
#   'Fancy Skulls',
#   'Canyon Capers - Rio Fever',
#   'XenoRaptor',
#   'Rush for Glory',
#   'PAYDAY 2: The Big Bank Heist',
#   'Cities in Motion 2: Players Choice Vehicle Pack',
#   'Rocksmith® 2014 – Godsmack - “Awake”',
#   'Rocksmith® 2014 – Godsmack - “I Stand Alone”',
#   'Rocksmith® 2014 – Godsmack - “Cryin’ Like a Bitch”',
#   'Rocksmith® 2014 – Godsmack - “Love-Hate-Sex-Pain”',
#   'Fantasy Grounds - 3.5E/PFRPG 1 on 1 Adventure #3 The Forbidden Hills',
#   'Beyond Space Remastered Edition',
#   'The Few',
#   'Pro Cycling Manager 2014',
#   'Call of Duty®: Ghosts - Bling Pack',
#   'Call of Duty®: Ghosts - Astronaut Special Character',
#   'Call of Duty®: Ghosts - Spectrum Pack',
#   'Call of Duty®: Ghosts - Heavy Metal Pack',
#   'Call of Duty®: Ghosts - Koi Pack',
#   'Call of Duty®: Ghosts - Fitness Pack',
#   'Call of Duty®: Ghosts - Extinction Pack',
#   '"Precisely Calibrated Stringstick" Bow',
#   'Call of Duty®: Ghosts - Unicorn Pack',
#   '"Unstable Anomaly" Sword',
#   '"Toy Knife" Dagger',
#   '"Lethargic Sentience" Wand',
#   '"Barely Attuned Magic Thingy" Staff',
#   'RIFT: Upgrade Bundle Pack',
#   'RIFT: Glory of the Ascended Pack',
#   'RIFT: Classic Collector’s Pack',
#   "RIFT: Laethys' Fortune Pack",
#   'MotoGP™14',
#   'MotoGP™14 Laguna Seca Red Bull US Grand Prix',
#   'The Banner Saga - Mod Content',
#   'Company of Heroes 2 - The Western Front Armies',
#   'ZAMB! Biomutant Extermination',
#   'CoH 2 - The Western Front Armies: US Forces',
#   'GRID Autosport - High Res Texture Pack',
#   'CoH 2 - The Western Front Armies: Oberkommando West',
#   'MotoGP™14 Season Pass',
#   'Rocksmith® 2014 – The Surfaris - “Wipe Out”',
#   'Rocksmith® 2014 – The Ventures - “Walk Don’t Run”',
#   'Rocksmith® 2014 – Dick Dale and His Del-Tones - “Misirlou”',
#   'Rocksmith® 2014 – Surf Rock Song Pack',
#   'GRID Autosport - Black Edition Pack',
#   'Sniper Elite 3 - Camouflage Weapons Pack',
#   'Sniper Elite 3 - Hunter Weapons Pack',
#   'Sniper Elite 3 - Allied Reinforcements Outfit Pack',
#   'Divinity: Original Sin (Classic)',
#   'Spoiler Alert',
#   'Euro Truck Simulator 2 - Polish Paint Jobs Pack',
#   'Euro Truck Simulator 2 - Canadian Paint Jobs Pack',
#   'Warface',
#   'Triblaster',
#   'Talisman - Character Pack #6 - Gambler',
#   'Momodora III',
#   'Monsters Ate My Birthday Cake',
#   "Fantasy Grounds - PFRPG Compatible Adventure: Cipactli's Maw - One on One Adventure #15",
#   'Fantasy Grounds - PFRPG Compatible Adventure: The Lost City of Bransik - One on One Adventure #16',
#   'Contraption Maker',
#   'Survivor Squad Demo',
#   'Claire',
#   'Q*bert: Rebooted',
#   'Deponia: The Complete Journey',
#   'Cult of the Wind',
#   'MouseCraft',
#   'Fantasy Grounds - PFRPG The Breaking of Forstor Nagar',
#   'Rocksmith® 2014 – The Libertines - “Can’t Stand Me Now”',
#   'Rocksmith® 2014 – The Libertines - “What Katie Did”',
#   'Rocksmith® 2014 – The Libertines - “Don’t Look Back Into The Sun”',
#   'Rocksmith® 2014 – The Libertines Song Pack',
#   'Heroes Rise: HeroFall Demo',
#   'Evil Pumpkin: The Lost Halloween',
#   'Retrobooster',
#   'Rooms: The Main Building',
#   'X-Plane 10 Global - 64 Bit - Europe Scenery',
#   'X-Plane 10 Global - 64 Bit - Africa Scenery',
#   'X-Plane 10 Global - 64 Bit - Asia Scenery',
#   'X-Plane 10 Global - 64 Bit - Australia Scenery',
#   'X-Plane 10 Global - 64 Bit',
#   'X-Plane 10 Global - 64 Bit - North America Scenery',
#   'X-Plane 10 Global - 64 Bit - South America Scenery',
#   'Pivvot',
#   'Tales of Adventure 2',
#   'Expansion - Europa Universalis IV: Res Publica',
#   'Europa Universalis IV: Republican Music Pack',
#   'Europa Universalis IV: Indian Ships Unit Pack',
#   'The Nightmare Cooperative',
#   'Magic 2015 - Duels of the Planeswalkers',
#   'Hero Siege - The Karp of Doom',
#   'Steel & Steam: Episode 1',
#   'EVGA Precision XOC',
#   'Europa Universalis IV: Indian Subcontinent Unit Pack',
#   'Hidden in Plain Sight',
#   'Scooby Doo! & Looney Tunes Cartoon Universe: Adventure',
#   'Rulers of Nations',
#   'Innistrad Card Collection',
#   'Theros Card Collection',
#   'Rocksmith® 2014 – The Doobie Brothers - “China Grove”',
#   'Sniper Elite 3 - Save Churchill Part 1: In Shadows',
#   'Sniper Elite 3 - Patriot Weapons Pack',
#   'Pixel Hunter',
#   'Point Perfect',
#   'The Forgotten Ones',
#   'Heileen 3 Bonus Content',
#   'Detective Case and Clown Bot in: Murder in the Hotel Lisbon',
#   'Pressured',
#   "Hero Siege - The Karp of Doom (Digital Collector's Edition)",
#   'Toxic Bunny HD',
#   'Ghostship Aftermath',
#   'Lantern Forge',
#   'Undead Overlord',
#   'Obludia',
#   'Time of Fury',
#   'Smugglers 5 DLC: The Smugglers Guild',
#   'Blade Symphony Original Soundtrack',
#   'AR-K',
#   'OMSI 2 Add-on AI-Articulated Bus for Vienna',
#   'Sokobond',
#   'Data Hacker: Initiation',
#   'My Ex-Boyfriend the Space Tyrant',
#   'Freedom Planet',
#   'DARK SOULS™ II Crown of the Sunken King',
#   'Dungeon Defenders Eternity',
#   'Nicole Bonus Content',
#   "Fantasy Grounds - PFRPG Rite Publishing's Adventure Quarterly #5",
#   'Dark Horizons: Mechanized Corps',
#   'Influent DLC - Pусский [Learn Russian]',
#   'DARK SOULS™ II - Season Pass',
#   'Velvet Sundown',
#   'Naviros Fashionista pack',
#   'Naviros Beginner pack',
#   'GRID Autosport - Best of British Pack',
#   'Third Eye Crime',
#   'GRID Autosport - Premium Garage Pack',
#   'Machines At War 3',
#   'Fantasy Grounds - PFRPG The Reaping Stone',
#   'CoH 2 - US Forces Commander: Rifle Company',
#   'CoH 2 - OKW Commander: Elite Armor Doctrine',
#   'CoH 2 - US Forces Commander: Recon Support Company',
#   'CoH 2 - US Forces Commander: Mechanized Company',
#   'CoH 2 - OKW Commander: Fortifications Doctrine',
#   'Defiance: VBI Ultimate Pack',
#   'Vertical Drop Heroes HD',
#   'Selknam Defense',
#   'The Room',
#   'Proxy Blade Zero',
#   'Fantasy Grounds - PFRPG: BASIC1 - A Learning Time',
#   'Rodina',
#   'Fantasy Grounds - PFRPG: BASIC2 - A Frightful Time',
#   'Us and the Game Industry',
#   'Rodina Soundtrack',
#   'Trials Fusion - Riders of the Rustlands',
#   'Rodina Demo',
#   'Black Ice Original Soundtrack - Level One',
#   'The Legend of Heroes: Trails in the Sky',
#   'Call of Duty®: Ghosts - Bling Character Pack',
#   'Top Hat',
#   'Guns and Robots - Starter Pack',
#   'Crazy Plant Shop',
#   'Jet Gunner',
#   'The Expendabros',
#   'Sacred 3',
#   'Rocksmith® 2014 – Biffy Clyro - “Black Chandelier”',
#   'Rocksmith® 2014 – Biffy Clyro - “Stingin’ Belle”',
#   'Rocksmith® 2014 – Biffy Clyro - “Bubbles”',
#   'GRID Autosport - Coupé Style Pack',
#   'The Counting Kingdom',
#   'Rocksmith® 2014 – Biffy Clyro - “Many of Horror”',
#   'Road Not Taken',
#   'Rocksmith® 2014 – Biffy Clyro - “Mountains”',
#   'Fantasy Grounds - Deadlands Noir',
#   'Orbital Gear',
#   'Ultra Street Fighter® IV Digital Upgrade',
#   'Naviros Samurai Pack',
#   'Graviteam Tactics: Shilovo 1942',
#   'Cricket Captain 2014',
#   'DCS: F-86F Sabre',
#   'The Terminal 2',
#   'GamersGoMakers',
#   'Victory At Sea',
#   'Frontline : Road to Moscow',
#   'Psichodelya',
#   'Wyv and Keep: The Temple of the Lost Idol',
#   'Train Simulator: Liverpool-Manchester Route Add-On',
#   'Another Perspective',
#   'Morphopolis',
#   "Collector's Edition DLC",
#   'Train Simulator: BR Regional Railways Class 101 DMU Add-On',
#   'Sniper Elite 3 - Eastern Front Weapons Pack',
#   'Mega Coin Squad',
#   "Aritana and the Harpy's Feather",
#   'Heavy Fire: Afghanistan',
#   "Aritana and the Harpy's Feather Demo",
#   'Pixeluvo',
#   'Kick-Ass 2',
#   'Divine Souls F2P MMO',
#   'DW8XLCE - NEW STAGE & CAMP SYMBOL PACK',
#   'DW8XLCE - WEAPON SYSTEM & UPGRADE PACK',
#   'DW8XLCE - WEAPON SYSTEM PACK',
#   'DW8XLCE - NEW STAGE & ANIMAL PACK',
#   'DW8XLCE - JAPANESE VOICE OPTION',
#   'DW8XLCE - ORIGINAL COSTUME PACK',
#   'Freedom Planet - Official Soundtrack',
#   'Sniper Elite 3 - Save Churchill Part 2: Belly of the Beast',
#   'Heroes & Legends: Conquerors of Kolhar',
#   'Guacamelee! Super Turbo Championship Edition',
#   'Jamsouls',
#   'Max Gentlemen',
#   'Fantasy Grounds - PFRPG: U1: Dark Days in Stoneholme',
#   'Shadowgate (2014)',
#   'Taxi',
#   'Character Creator - Graphics Pack',
#   'Space Galaxy - Graphics Pack',
#   'Commando Jack',
#   'Cubesis',
#   'Cannons Lasers Rockets',
#   'Deep Under the Sky',
#   'Dark Scavenger Demo',
#   'Bravada Demo',
#   'Super Time Force Ultra',
#   'The Journey Down: Chapter Two',
#   'Biglands: A Game Made By Kids',
#   'Super Time Force Ultra - Soundtrack',
#   'Metro 2033 Redux',
#   'Metro: Last Light Redux',
#   'See No Evil',
#   'See No Evil - Official Soundtrack',
#   'DARK SOULS™ II Crown of the Old Iron King',
#   'Rocksmith® 2014 – Bachsmith',
#   'Lichdom: Battlemage',
#   'Airship Dragoon',
#   'GRID Autosport - Sprint Pack',
#   'Fantasy Grounds - Deadlands Noir: The Case of the Jumbo Shrimp',
#   'Trainz Trouble',
#   'Airship Dragoon Demo',
#   'Train Town',
#   'Appointment With FEAR',
#   "Nobunaga's Ambition: Souzou - Scenario Tenkafubu",
#   'Zombie Driver HD Brutal Car Skins',
#   'Nobunaga\'s Ambition: Souzou - "Motonobu Serada", "Tsuru Oohouri" Bushou Data',
#   "Nobunaga's Ambition: Souzou - Nobunaga Oda In-Game Face CG",
#   'Nobunaga\'s Ambition: Souzou - "Goemon Ishikawa", "Yasuke" Bushou Data',
#   'Nobunaga\'s Ambition: Souzou - "Teru Kushihashi", "Chiyome Mochiduki" Bushou Data',
#   'Fantasy Grounds - Deadlands Reloaded: Blood Drive 1',
#   'Nobunaga\'s Ambition: Souzou - "Nobunaga\'s Ambition Day" memorial set',
#   "Nobunaga's Ambition: Souzou - Series 30th Anniversary Contents",
#   'Monkey Tales Games',
#   'Draconian Wars',
#   'Awesomenauts - Leon Legionnaire Skin',
#   'Awesomenauts - Jotunn Skølldir Skin',
#   'Awesomenauts - Grim Genji Skin',
#   'GoD Factory: Wingmen',
#   'Power-Up',
#   'Millennium 3 - Cry Wolf',
#   'Minimum',
#   'Dragons and Titans - Titan Pass',
#   'Train Simulator: Norfolk Southern Dash8-40C Loco Add-On',
#   'OMSI 2 Add-on Hamburg',
#   'Altitude0: Lower & Faster',
#   'Talisman - Character Pack #8 - Apprentice Mage',
#   'Dwelvers',
#   'One Day For Ched',
#   'The Flying Dutchman',
#   'Fable Anniversary - Heroes and Villains Content Pack',
#   'Fable Anniversary',
#   'Fable Anniversary - Scythe Content Pack',
#   'Lords of the Black Sun',
#   'Jacob Jones and the Bigfoot Mystery : Episode 1',
#   'The Collider',
#   'Great Permutator',
#   'Color Symphony',
#   'Shadowcrypt',
#   'Reprisal Universe',
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution - DLC4 Jinchuriki Costume Pack 1',
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution - DLC5 Jinchuriki Costume Pack 2',
#   'Hero of Many - Original Soundtrack',
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution',
#   'Hero of Many',
#   'Near Impact',
#   'My Lands: Black Gem Hunting',
#   'Movie Edit Pro 2015 - Movie Templates',
#   'My Lands: Miner’s Luck - Starter DLC Pack',
#   'The Waste Land',
#   'My Lands: Golden Age - Premium DLC Pack',
#   'My Lands: Miner’s Luck - Extended DLC Pack',
#   'My Lands: Elf Ranger - Artifact DLC Pack',
#   'My Lands: Nomad - Artifact DLC Pack',
#   'My Lands: Hero Courage - Extended DLC Pack',
#   'My Lands: Age of Prosperity - Premium DLC Pack',
#   'Endless Legend™',
#   'WAKFU',
#   'Elminage Gothic',
#   'Heavy Bullets',
#   'Pro Rugby Manager 2015',
#   'War Operations',
#   'Age of Wonders III - Golden Realms Expansion',
#   'Secret of the Magic Crystals - Soundtrack and Coloring Book',
#   'WAKFU - Magmog Pack',
#   'WAKFU - Excarnus Pack',
#   'Enola',
#   "Wasteland 2: Director's Cut",
#   'Zen Fish SIM',
#   'Cannon Brawl',
#   'Cho Dengeki Stryker All Ages Version',
#   'The Last Federation - Betrayed Hope',
#   'Super Chain Crusher Horizon',
#   'Magicmaker',
#   'Stronghold Crusader 2',
#   'Fritz Chess 14',
#   'Bionic Heart 2 Bonus Content',
#   'Jacob Jones and the Bigfoot Mystery : Episode 2',
#   'Deep Fritz 14 DLC',
#   'Ancient Space',
#   'DG2: Defense Grid 2',
#   'Rocksmith® 2014 – Shinedown - “45”',
#   'Rocksmith® 2014 – Shinedown - “Bully”',
#   'Pier Solar and the Great Architects',
#   'Sherlock Holmes: Crimes and Punishments',
#   'DARK SOULS™ II Crown of the Ivory King',
#   'Artbook and OST',
#   'Middle-earth: Shadow of Mordor - GOTY Edition Upgrade',
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution - DLC6 Suit Pack',
#   'Influent DLC - Italiano [Learn Italian]',
#   'Rocksmith® 2014 – Foreigner - “Cold As Ice”',
#   'Rocksmith® 2014 – Foreigner - “Hot Blooded”',
#   'Rocksmith® 2014 – Foreigner - “Feels Like The First Time”',
#   'Rocksmith® 2014 – Foreigner - “Juke Box Hero”',
#   'Rocksmith® 2014 – Foreigner Song Pack',
#   'Middle-earth™: Shadow of Mordor™',
#   'Wrack',
#   'Super Win the Game Soundtrack',
#   'Euro Truck Simulator 2 - German Paint Jobs Pack',
#   'Rocksmith® 2014 – Foreigner - “Double Vision”',
#   'Super Win the Game',
#   'Silence of the Sleep',
#   'Double Action Dedicated Server',
#   'Prime World - Advanced Pack',
#   'Train Simulator: West Highland Line Extension Route Add-On',
#   'Depth Hunter 2: Ocean Mysteries',
#   'Hegemony Rome: The Rise of Caesar - Mercenaries Pack',
#   'Fantasy Grounds - Savage Worlds: ETU - East Texas University',
#   'Front Page Sports Football',
#   'METAL SLUG X',
#   'Qora',
#   'A Golden Wake Demo',
#   'Qora - Soundtrack',
#   'DCS: MiG-21Bis',
#   'Shan Gui OST',
#   "Disney Fairies: Tinker Bell's Adventure",
#   'Metal Dead',
#   'Styx: Master of Shadows',
#   'Counter-Strike Nexon: Zombies',
#   'Alien: Isolation - Deluxe Edition DLC',
#   'Crow',
#   'Costume Quest 2',
#   'Trials Fusion - Welcome to the Abyss',
#   'CRYENGINE - Wwise Project DLC',
#   'Alien: Isolation - Last Survivor',
#   'Fantasy Grounds - Maps: Winding Caverns',
#   'Fantasy Grounds - Maps: Cobblestone City and Inn',
#   'Fantasy Grounds - Maps: Graystone Castle',
#   'Pinball Arcade: Season Four Pack',
#   'Pinball Arcade: Season Four Pro Pack',
#   "Dragon's Prophet: Free Pack",
#   '1HEART',
#   'Sigils of Elohim',
#   'The Evil Within Season Pass',
#   'The Evil Within',
#   'Deep Dungeons of Doom',
#   'Graviteam Tactics: Operation Hooper',
#   'Tropico 5 - Generalissimo',
#   'Official Fenix Rage Game Soundtrack',
#   'Killing Floor - Toy Master',
#   'A City Sleeps™',
#   'A City Sleeps - Soundtrack',
#   'Fenix Rage Demo',
#   'Ultimate General: Gettysburg',
#   "Black Viper: Sophia's Fate",
#   'Smugglers 5: Invasion',
#   'F1 2014',
#   'Man in a Maze: Deathmatch',
#   'Middle-earth: Shadow of Mordor - Test of Wisdom',
#   'Time Rifters',
#   'Rocksmith® 2014 – Dio - “Holy Diver”',
#   'Rocksmith® 2014 – Winger - “Seventeen”',
#   'Rocksmith® 2014 – Autograph - “Turn Up The Radio”',
#   'Rocksmith® 2014 – Billy Squier - “The Stroke”',
#   "Devil's Dare 悪魔の挑戦",
#   'Rocksmith® 2014 – Poison - “Nothin’ But A Good Time”',
#   'Screencheat',
#   'MotoGP™14 Donington Park British Grand Prix DLC',
#   'Vampires: Guide Them to Safety! - Soundtrack',
#   'X-Plane 10 AddOn - Carenado - PA28 181 Archer II',
#   'Warlock 2: The Thrilling Trio',
#   'Life of Pixel',
#   'Sacred 3. Orcland Story',
#   'Vampires: Guide Them to Safety!',
#   'Sniper Elite 3 - International Camouflage Rifles Pack',
#   'Awesomenauts - Wraithlord Scoop Skin',
#   'The Count of Monster Disco',
#   'Sign Motion',
#   'Robowars',
#   'Sproggiwood',
#   'Enforcer: Police Crime Action',
#   'Sky Nations Demo',
#   'REVOLVER360 RE:ACTOR',
#   'TesserAct',
#   'Euro Truck Simulator 2 - Czech Paint Jobs Pack',
#   'theHunter: Pathfinder Starter Pack',
#   'theHunter : Trailrunner Starter Pack',
#   'Rocksmith® 2014 – The Killers Song Pack',
#   'Dungeon Lurk II - Leona',
#   'Spacebase DF-9',
#   'Tower of Guns Soundtrack',
#   'Daedalus - No Escape',
#   'The Moon Sliver',
#   'BlazeRush',
#   'Middle-earth: Shadow of Mordor - Endless Challenge',
#   'X-Plane 10 AddOn - Carenado - C172N Skyhawk II',
#   'QbQbQb',
#   "Train Simulator: BR Class 45 'Peak' Loco Add-On",
#   'The Moon Sliver - Extended Soundtrack',
#   'Tail Drift',
#   'Farming Simulator 15',
#   'Vertical Drop Heroes - Halloween Theme',
#   'Miscreated',
#   'Cosmic DJ',
#   'Europa Universalis IV: Art of War Ebook',
#   'Battlepaths - Soundtrack',
#   'Alea Jacta Est Spartacus 73BC',
#   'Alea Jacta Est Cantabrian Wars',
#   'Aviator - Bush Pilot',
#   'The Binding of Isaac: Rebirth',
#   'Arma 3 Helicopters',
#   'Defenders of Time',
#   'Space Warp',
#   'Rocksmith® 2014 – Killswitch Engage - “The End Of Heartache”',
#   'Rocksmith® 2014 – Killswitch Engage - “My Curse”',
#   'Rocksmith® 2014 – Killswitch Engage - “Holy Diver”',
#   'Rocksmith® 2014 – Killswitch Engage Song Pack',
#   'Fantasy Grounds - C&C: Rune Lore',
#   'The World II: Hunting BOSS',
#   'Among the Sleep: Prologue',
#   'The Joylancer: Legendary Motor Knight',
#   "Winged Sakura: Mindy's Arc - Soundtrack",
#   "Winged Sakura: Mindy's Arc",
#   'Pitiri 1977',
#   'GRID Autosport - Demoman Derby Pack',
#   'Crowntakers',
#   'Pirate Hell',
#   'A Bird Story',
#   'Gunspell - Steam Edition',
#   'A Bird Story - Original Soundtrack',
#   'Gold Rush! Anniversary',
#   'Rocksmith® 2014 – Tom Petty Song Pack',
#   'MASSIVE CHALICE Soundtrack',
#   'Deadlings: Rotten Edition',
#   'Toybox Turbos',
#   'Space Hulk Ascension',
#   'Leadwerks Game Engine - FPS Weapons Pack',
#   'Anodyne OST',
#   'Amphora',
#   'Chariot',
#   'Chariot - Soundtrack',
#   "Randal's Monday",
#   'Deadstone',
#   'Middle-earth: Shadow of Mordor - Rising Storm Rune',
#   'Sneaky Sneaky',
#   'LEGO Batman 3: Beyond Gotham DLC: Man of Steel',
#   'Rocksmith® 2014 – Foo Fighters - “Long Road to Ruin”',
#   'LEGO Batman 3: Beyond Gotham DLC: Batman 75th Anniversary',
#   'Company of Heroes 2 - Ardennes Assault',
#   'Fantasy Grounds - Deadlands Reloaded: Blood Drive 3',
#   'Inside The Gear Demo',
#   'Company of Heroes 2 - Ardennes Assault: Fox Company Rangers',
#   'Far Cry® 4',
#   'Far Cry® 4 Season Pass',
#   'Ski-World Simulator',
#   'The Blue Flamingo',
#   'Cities in Motion: Soundtrack',
#   'KEL Reaper of Entropy',
#   'Never Alone (Kisima Ingitchuna)',
#   'Cities in Motion 2: Soundtrack',
#   'Escape Dead Island',
#   'Solar Struggle',
#   'Adventure Time: The Secret Of The Nameless Kingdom',
#   'Gems of War - Puzzle RPG',
#   'Fantasy Grounds - Counter Collection 4E Paragon 1',
#   'WARMACHINE: Tactics',
#   'Rock Zombie',
#   'Death Skid Marks Soundtrack',
#   "Letter Quest: Grimm's Journey",
#   'Death Skid Marks',
#   'Celestial Command',
#   'Passing Pineview Forest',
#   'MotoGP™14 Compact',
#   'Amazing Frog?',
#   'AppGameKit: Easy Game Development',
#   'Inside The Gear',
#   'Kinetic Void',
#   'Guns and Robots - Veteran Pack',
#   'Draft Day Sports Pro Basketball 4',
#   'Luna: Shattered Hearts: Episode 1',
#   'Space Legends: At the Edge of the Universe',
#   'Train Simulator: BR 6MT Clan Class Loco Add-On',
#   'Brink of Consciousness: The Lonely Hearts Murders',
#   'Craft The World',
#   "Axis Game Factory's AGFPRO BattleMat Multi-Player DLC",
#   'Chivalry: Medieval Warfare and Chivalry: Deadliest Warrior - Soundtrack',
#   "Midnight Mysteries: Witches of Abraham - Collector's Edition",
#   'Space Salvager Demo',
#   'Shroud of the Avatar: Forsaken Virtues',
#   'Haunted House: Cryptic Graves',
#   'Rocksmith® 2014 – Bullet For My Valentine - “Tears Don’t Fall”',
#   'Alien: Isolation - Trauma',
#   'Tesla Breaks the World Official Soundtrack',
#   'Middle-earth: Shadow of Mordor - Berserks Warband',
#   'Tesla Breaks the World!',
#   "Sid Meier's Civilization: Beyond Earth Exoplanets Map Pack",
#   'X-Plane 10 AddOn - Carenado - PA34 200T Seneca II',
#   'Atajrubah',
#   'The Witcher Adventure Game',
#   "Joe Dever's Lone Wolf HD Remastered",
#   '100% Orange Juice - Saki & Kyousuke Character Pack',
#   'Wings of Vi',
#   'Motorcycle Club',
#   'Mining Industry Simulator',
#   'Beach Resort Simulator',
#   'Train Simulator: N15 King Arthur Class ‘Sir Lamiel’ Loco Add-On',
#   'Sanctum 2: Original Soundtrack',
#   'ULTRAWORLD EXODUS',
#   "Insanity's Blade",
#   'ULTRAWORLD + EXODUS Soundtrack',
#   'Train Simulator: BR 266 Loco Add-On',
#   'Train Simulator: West Rhine: Köln - Koblenz Route Add-On',
#   'Mecha Ace Demo',
#   'Galcon 2: Galactic Conquest',
#   'Mecha Ace',
#   'Escape From Darkmoor Manor',
#   'Bin Weevils Arty Arcade',
#   'iO',
#   'Lambda Wars Beta',
#   'Millie Demo',
#   'Train Simulator: GWR Small Prairies Loco Add-On',
#   'Elegy for a Dead World',
#   'Gauntlet - Lilith the Necromancer Pack',
#   'JUJU',
#   'Prelogate',
#   'Rock Boshers DX: Directors Cut',
#   'Rexaura',
#   'POP: Methodology Experiment One - Game of The Saeculum Edition DLC',
#   'Battle of Empires : 1914-1918 - Editor',
#   'Battle of Empires : 1914-1918 - French campaign',
#   'Enforcer: Original Soundtrack',
#   'Influent DLC - Português [Learn European Portuguese]',
#   "Letter Quest: Grimm's Journey Demo",
#   'FINAL FANTASY® XIII-2',
#   'Final Dusk',
#   'bit Dungeon II',
#   'Tkl Online Demo',
#   'SunAge: Battle for Elysium',
#   'LISA',
#   'Depth - SDK',
#   'Town of Salem',
#   'National Zombie Park',
#   'Metrocide',
#   'FRONTIERS',
#   'LISA: Original Soundtrack + Art Collection',
#   'Rocksmith® 2014 – Jimi Hendrix Song Pack I',
#   'Rocksmith® 2014 – Jimi Hendrix - “Manic Depression”',
#   'Rocksmith® 2014 – Jimi Hendrix - “Bold As Love”',
#   'Rocksmith® 2014 – Jimi Hendrix - “Foxey Lady”',
#   'SanctuaryRPG: Black Edition Demo',
#   'Rocksmith® 2014 – Jimi Hendrix - “Castles Made Of Sand”',
#   'Graviteam Tactics: Hi-Res Textures',
#   'Graviteam Tactics: Krasnaya Polyana 1943',
#   'USFIV: Shoryuken Wild Pack',
#   'USFIV: Brawler Wild Pack',
#   'USFIV: Classic Wild Pack',
#   'USFIV: Shadaloo Wild Pack',
#   'USFIV: Femme Fatale Wild Pack',
#   'USFIV: Challengers Wild Pack 2',
#   'USFIV: Challengers Wild Pack 1',
#   'Dead Effect',
#   'World Of Leaders',
#   'Mission Control: NanoMech',
#   'World Of Leaders - Premium Pack',
#   'World Of Leaders - Starter Pack',
#   "Fork Parker's Holiday Profit Hike",
#   'METAL GEAR SOLID V: GROUND ZEROES',
#   'Train Simulator: Miami - West Palm Beach Route Add-On',
#   'Verde Station',
#   'Gates of Horizon',
#   'BLOCKADE 3D',
#   'Do Not Fall',
#   'I Will Escape',
#   'Choice of Robots',
#   'Antisquad: Tasks in Mexico - The Beginning. Tactics FREE DLC',
#   'Antisquad: Tasks in Mexico - Final. Tactics DLC',
#   'Psy High',
#   'Psy High Demo',
#   'Geometry Dash',
#   'Pilot Brothers 2',
#   'Catmouth Island',
#   'Shadows of War',
#   'Unhack Demo',
#   'Countless Rooms of Death',
#   "Witch's Pranks: Frog's Fortune Collector's Edition",
#   'Unhack - Original Soundtrack',
#   'Bit Odyssey',
#   'Tales of Aravorn: Seasons Of The Wolf Demo',
#   'Wickland',
#   'Boring Man - Online Tactical Stickman Combat',
#   'Time Mysteries: Inheritance - Remastered',
#   'Hospital Manager',
#   'TDP5 Arena 3D',
#   'Claws & Feathers',
#   'Grim Legends 2: Song of the Dark Swan',
#   'Voices from the Sea - Plus',
#   'BattleLore: Command',
#   'Copa Petrobras de Marcas',
#   'Domestic Dog',
#   'Halo: Spartan Strike',
#   'Super Furball',
#   "Virus Jigglin' Fever",
#   'Vertiginous Golf',
#   'Grail to the Thief',
#   'AdvertCity Soundtrack',
#   'Good Game',
#   'How We Got Away With It',
#   'Starship Rubicon',
#   ...]}

# %% [markdown]
# ### Función #3

# %%
#  Se ingresa un año y devuelve una lista con los 5 specs que más se repiten en el mismo en el orden correspondiente.

def get_specs(year):
    filtered_specs = data[data['year'] == str(year)]
    specs = [spec for lista in filtered_specs['specs'] if isinstance(lista, list) for spec in lista if pd.notna(spec)]
    specs_dict = {spec: specs.count(spec) for spec in specs}
    top_specs = dict(sorted(specs_dict.items(), key=lambda x: x[1], reverse=True)[:5])
    return top_specs

get_specs(1996)
# Out:
# {'Single-player': 36,
#  'Multi-player': 9,
#  'Steam Trading Cards': 6,
#  'Steam Cloud': 4,
#  'Captions available': 3}

# %% [markdown]
# ### Función #4

# %%
#  Cantidad de juegos lanzados en un año con early access

def get_early_access(year):
    filtered_early_access = data[data['year'] == str(year)]
    early_access_count = filtered_early_access[filtered_early_access['early_access'] == True].shape[0]
    early_access_dict = {year: early_access_count}
    return early_access_dict

get_early_access(2016)
# Out:
# {2016: 363}

# %% [markdown]
# ### Función #5

# %%
# Según el año de lanzamiento, se devuelve un diccionario con la cantidad de registros que se encuentren categorizados con un análisis de sentimiento.

def get_sentiment(year):
    sentiments = ['Mixed', 'Mostly Negative', 'Mostly Positive', 'Negative', 'Overwhelmingly Negative',
                  'Overwhelmingly Positive', 'Positive', 'Very Negative', 'Very Positive']
    filtered_sentiment = data[data['year'] == str(year)]
    filtered_sentiment = filtered_sentiment[filtered_sentiment['sentiment'].isin(sentiments)]
    sentiment_list = [x for x in filtered_sentiment['sentiment'] if pd.notna(x)]
    sentiment_dict = {sentiment: sentiment_list.count(sentiment) for sentiment in sentiment_list}
    return dict(sorted(sentiment_dict.items(), key=lambda x: x[1], reverse=True))

get_sentiment(2014)
# Out:
# {'Mixed': 468,
#  'Very Positive': 431,
#  'Mostly Positive': 335,
#  'Positive': 238,
#  'Mostly Negative': 99,
#  'Overwhelmingly Positive': 37,
#  'Negative': 27,
#  'Very Negative': 7,
#  'Overwhelmingly Negative': 1}

# %% [markdown]
# ### Función #6

# %%
# Top 5 juegos, según año, con mayor metascore.

def get_metascore(year):
    filtered_metascore = data[(data['year'] == str(year)) & (data['metascore'] != 'NA')]
    filtered_metascore = filtered_metascore.dropna(subset=['metascore'])
    sorted_metascore = filtered_metascore.sort_values('metascore', ascending=False)
    top_data = sorted_metascore.head(5)[['app_name', 'metascore']]
    if top_data.empty:
        metascore_dict = {'Data not found'}
    else:
        metascore_dict = top_data.set_index('app_name')['metascore'].to_dict()
    return metascore_dict

get_metascore(2012)
# Out:
# {'Batman: Arkham City - Game of the Year Edition': 91,
#  'Dishonored': 91,
#  'Mark of the Ninja': 91,
#  'XCOM: Enemy Unknown': 89}
